# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjay-agalave/python/blob/main/BDD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #

# %% [markdown]
# Understand:
#
# What is software testing
#
# SDLC (Software Development Life Cycle)
#
# STLC (Software Testing Life Cycle)
#
#
#
# 1. What is Software Testing?
#
# Testing = verifying that software works as expected
#
# Examples:
#
# Login works correctly
#
# Error shown for wrong password
#
#
#
#
#
# 2. SDLC (High Level)
#
# Learn these stages:
#
# Requirement gathering
#
# Design
#
# Development
#
# Testing
#
# Deployment
#
# Focus: testing comes after development
#
#
#
# 3. STLC (Testing Steps)
#
# Requirement analysis
#
# Test planning
#
# Test case design
#
# Test execution
#
# Defect reporting
#
#
#
#
#
# Task: Write 5 real-world testing examples
#
# Test Case ID: TC_WMS_001
#
# Title: Verify navigation and functionality of all pages in WMS application
#
#
# 🔹 Pre-Conditions:
#
# User should have valid login credentials
#
# Application URL should be accessible
#
#
#
# 🔹 Test Steps:
#
# Open browser and navigate to:
# 👉 https://us1-sq3.wysemanagementsuite.com/ccm-web/login
#
# Enter valid credentials:
#
# Username: sanjay.agalave1@dellteam.com
#
# Password: Dell#1234567
#
# Click on Sign In button
#
# Verify Dashboard loads successfully
#
# Validate below sections in Dashboard:
#
# Alerts
#
# Jobs
#
# Non-compliance
#
# Events
#
#
#
# Navigate to Groups & Configs
#
# Verify pages:
#
# Unmanaged Group
#
# Default Device Policy Group
#
# Default User Policy Group
#
#
#
# Navigate to Devices
#
# Click on any Device ID
#
#
#
# Navigate to App & Data and scroll down
#
# Navigate to Thin Client (App Policies)
#
#
#
# Navigate to Waves
#
# Click Create Wave
#
#
#
# Navigate to Rules and verify page loads
#
#
#
# Navigate to Jobs
#
# Scroll down
#
# if pagination (Next button) is enabled → click Next and verify results
#
#
#
# Navigate to Events
#
# Scroll down
#
# If pagination enabled → click Next
#
#
#
# Navigate to Users → Administrator
#
# Navigate to Portal Administration → Subscription
#
# Scroll down and verify data
#
#
#
#  Expected Result:
#
# User should successfully log in
#
# All pages should:
#
# Load without errors
#
# Display correct data
#
# Support navigation (scroll/pagination works)
#
# No crashes, broken UI, or incorrect data

# %% [markdown]
# Step 1: Simple Understanding
#
#  Functional Testing
#
# Checks what the system does
#
# Examples:
#
# Login works
#
# Button click works
#
# Data saving works
#
#
#
#
# Non-Functional Testing
#
#  Checks how the system performs
#
# Examples:
#
# Performance (speed)
#
# Security
#
# Usability
#
# Load handling
#
#
#
#
#  Classify the below scenarios
#
#
#
#  Scenarios:
#
# User logs in with valid credentials
#
# Page loads within 2 seconds
#
# Password is encrypted
#
# Add item to cart works
#
# System handles 1000 users at same time
#
# Error message shows for invalid login
#
# Website works on mobile and desktop
#
# Data is saved correctly in database

# %% [markdown]
# 1. What is a Test Case?
#
#  A test case is a structured way to verify functionality.
#
# It contains:
#
# Title
#
# Preconditions
#
# Steps
#
# Expected Result
#
#
#
#
#  2. Login Test Cases (Professional Format)
#
#  Test Case 1: Valid Login
#
#       Test Case ID: TC_LOGIN_001
#
# Title: Verify login with valid credentials
#
# 🔹 Preconditions:
#
# User has valid username and password
#
# Application is accessible
#
#
# 🔹 Steps:
#
# Open browser
#
# Navigate to login page
#
# Enter valid username
#
# Enter valid password
#
# Click on login button
#
#
# Expected Result:
#
# User should be logged in successfully
#
# Dashboard should be displayed
#
#
#
#
#
#  Test Case 2: Invalid Password
#
#  Test Case ID: TC_LOGIN_002
#
# Title: Verify login with invalid password
#
# 🔹 Preconditions:
#
# User exists
#
#
#
# 🔹 Steps:
#
# Open login page
#
# Enter valid username
#
# Enter wrong password
#
# Click login
#
#
#
#
#  Expected Result:
#
# Error message displayed
#
# Login should fail
#
#
#
#
#
#  Test Case 3: Empty Fields
#
#       Test Case ID: TC_LOGIN_003
#
# Title: Verify login with empty fields
#
# 🔹 Steps:
#
# Open login page
#
# Leave username empty
#
# Leave password empty
#
# Click login
#
#
#
#  Expected Result:
#
# Validation message should appear
#
#
#
#
#
#  Test Case 4: Invalid Username
#
# Test Case ID: TC_LOGIN_004
#
# Title: Verify login with invalid username
#
# 🔹 Steps:
#
# Open login page
#
# Enter invalid username
#
# Enter password
#
# Click login
#
#
#
#  Expected Result:
#
# Login should fail
#
# Error message displayed
#
#
#
#
#  3. Login Test Steps (Automation Ready)
#
#  These steps will directly convert into BDD later
#
#
# Common Steps
#
# 1. Open browser
# 2. Navigate to login page
# 3. Enter username
# 4. Enter password
# 5. Click login button
# 6. Verify result
#
#
#
#  Example (Valid Login Flow)
#
# Step 1: Open browser
# Step 2: Go to WMS login page
# Step 3: Enter username: valid_user
# Step 4: Enter password: valid_pass
# Step 5: Click Sign In
# Step 6: Verify dashboard is displayed
#
#
#
#  Example (Invalid Login Flow)
#
# Step 1: Open browser
# Step 2: Go to login page
# Step 3: Enter valid username
# Step 4: Enter wrong password
# Step 5: Click Sign In
# Step 6: Verify error message is shown
#
#
#
#  4. Convert to BDD (Preview for Day 5)
#
#  Same test case in BDD:
#
# Scenario: Valid login
#
#
#
# Given user is on login page
# When user enters valid username
# And user enters valid password
# And user clicks login button
# Then dashboard should be displayed
